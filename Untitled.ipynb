# %%
df1=pd.read_csv('student-mat1.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-af8ebfd9fc52> in <module>
# ----> 1 df1=pd.read_csv('student-mat1.csv')
#
# NameError: name 'pd' is not defined

# %%
df2=pd.read_csv('student-por.csv')

# %%
df=pd.read_csv('student-mat1.csv')

# %%
df['Dalc']=df['Dalc']+df['Walc']

# %%
df.drop(columns=['Walc'],inplace=True)

# %%
df.loc[df['school'] == 'GP', 'school'] = 1
df.loc[df['school'] == 'MS', 'school'] = 0

df.loc[df['sex'] == 'M', 'sex'] = 1
df.loc[df['sex'] == 'F', 'sex'] = 0

df.loc[df['address'] == 'U', 'address'] = 1
df.loc[df['address'] == 'R', 'address'] = 0

df.loc[df['famsize'] == 'GT3', 'famsize'] = 1
df.loc[df['famsize'] == 'LE3', 'famsize'] = 0

df.loc[df['Pstatus'] == 'T', 'Pstatus'] = 1
df.loc[df['Pstatus'] == 'A', 'Pstatus'] = 0

# %%
for col in['schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']:
    df[col] = df[col].map({'yes': 1, 'no': 0})

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        1   0   18       1       1       0     4     4   at_home   teacher
# 1        1   0   17       1       1       1     1     1   at_home     other
# 2        1   0   15       1       0       1     1     1   at_home     other
# 3        1   0   15       1       1       1     4     2   mhealth  services
# 4        1   0   16       1       1       1     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390      0   1   20       1       0       0     2     2  services  services
# 391      0   1   17       1       0       1     3     1  services  services
# 392      0   1   21       0       1       1     1     1     other     other
# 393      0   1   18       0       0       1     3     2  services     other
# 394      0   1   19       1       0       1     1     1     other   at_home
#
#      ... romantic famrel  freetime  goout  Dalc  health  absences  G1  G2  G3
# 0    ...        0      4         3      4     2       3         6   5   6   6
# 1    ...        0      5         3      3     2       3         4   5   5   6
# 2    ...        0      4         3      2     5       3        10   7   8  10
# 3    ...        1      3         2      2     2       5         2  15  14  15
# 4    ...        0      4         3      2     3       5         4   6  10  10
# ..   ...      ...    ...       ...    ...   ...     ...       ...  ..  ..  ..
# 390  ...        0      5         5      4     9       4        11   9   9   9
# 391  ...        0      2         4      5     7       2         3  14  16  16
# 392  ...        0      5         5      3     6       3         3  10   8   7
# 393  ...        0      4         4      1     7       5         0  11  12  10
# 394  ...        0      3         2      3     6       5         5   8   9   9
#
# [395 rows x 32 columns]

# %%
df['Dalc']=[1 if i>5 else 0 for i in df.Dalc]

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        1   0   18       1       1       0     4     4   at_home   teacher
# 1        1   0   17       1       1       1     1     1   at_home     other
# 2        1   0   15       1       0       1     1     1   at_home     other
# 3        1   0   15       1       1       1     4     2   mhealth  services
# 4        1   0   16       1       1       1     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390      0   1   20       1       0       0     2     2  services  services
# 391      0   1   17       1       0       1     3     1  services  services
# 392      0   1   21       0       1       1     1     1     other     other
# 393      0   1   18       0       0       1     3     2  services     other
# 394      0   1   19       1       0       1     1     1     other   at_home
#
#      ... romantic famrel  freetime  goout  Dalc  health  absences  G1  G2  G3
# 0    ...        0      4         3      4     0       3         6   5   6   6
# 1    ...        0      5         3      3     0       3         4   5   5   6
# 2    ...        0      4         3      2     0       3        10   7   8  10
# 3    ...        1      3         2      2     0       5         2  15  14  15
# 4    ...        0      4         3      2     0       5         4   6  10  10
# ..   ...      ...    ...       ...    ...   ...     ...       ...  ..  ..  ..
# 390  ...        0      5         5      4     1       4        11   9   9   9
# 391  ...        0      2         4      5     1       2         3  14  16  16
# 392  ...        0      5         5      3     1       3         3  10   8   7
# 393  ...        0      4         4      1     1       5         0  11  12  10
# 394  ...        0      3         2      3     1       5         5   8   9   9
#
# [395 rows x 32 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
dummies=pd.get_dummies(df.Mjob)
merged=pd.concat([df,dummies],axis='columns')
df=merged

# %%
dummies=pd.get_dummies(df.Fjob)
merged=pd.concat([df,dummies],axis='columns')
df=merged

# %%
df.drop(columns=['Mjob','Fjob'],inplace=True)

# %%
dummies=pd.get_dummies(df.reason)
merged=pd.concat([df,dummies],axis='columns')
df=merged

# %%
dummies=pd.get_dummies(df.guardian)
merged=pd.concat([df,dummies],axis='columns')
df=merged

# %%
df.drop(columns=['reason','guardian'],inplace=True)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu  traveltime  \
# 0        1   0   18       1       1       0     4     4           2
# 1        1   0   17       1       1       1     1     1           1
# 2        1   0   15       1       0       1     1     1           1
# 3        1   0   15       1       1       1     4     2           1
# 4        1   0   16       1       1       1     3     3           1
# ..     ...  ..  ...     ...     ...     ...   ...   ...         ...
# 390      0   1   20       1       0       0     2     2           1
# 391      0   1   17       1       0       1     3     1           2
# 392      0   1   21       0       1       1     1     1           1
# 393      0   1   18       0       0       1     3     2           3
# 394      0   1   19       1       0       1     1     1           1
#
#      studytime  ...  other  services  teacher  course  home  other  \
# 0            2  ...      0         0        1       1     0      0
# 1            2  ...      1         0        0       1     0      0
# 2            2  ...      1         0        0       0     0      1
# 3            3  ...      0         1        0       0     1      0
# 4            2  ...      1         0        0       0     1      0
# ..         ...  ...    ...       ...      ...     ...   ...    ...
# 390          2  ...      0         1        0       1     0      0
# 391          1  ...      0         1        0       1     0      0
# 392          1  ...      1         0        0       1     0      0
# 393          1  ...      1         0        0       1     0      0
# 394          1  ...      0         0        0       1     0      0
#
#      reputation  father  mother  other
# 0             0       0       1      0
# 1             0       1       0      0
# 2             0       0       1      0
# 3             0       0       1      0
# 4             0       1       0      0
# ..          ...     ...     ...    ...
# 390           0       0       0      1
# 391           0       0       1      0
# 392           0       0       0      1
# 393           0       0       1      0
# 394           0       1       0      0
#
# [395 rows x 45 columns]

# %%
df.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# schoolsup  -0.251811 -0.036029  0.037530   -0.009246   0.037763 -0.000437
# famsup     -0.140609  0.183727  0.185496   -0.003286   0.145228 -0.055075
# paid       -0.035933  0.159700  0.086981   -0.066420   0.167220 -0.188039
# services    0.007309 -0.014818  0.013857
# teacher    -0.123040  0.153480 -0.070746
# at_home     0.012197 -0.020563  0.016071
# fhealth     0.083893 -0.064122 -0.020387
# other      -0.187335  0.154429  0.026485
# services    0.130369 -0.130637  0.020799
# teacher     0.055363 -0.000904 -0.083576
# course     -0.025519  0.065761 -0.072124
# home        0.015725 -0.065389  0.086550
# other      -0.004247  0.021304 -0.029545
# reputation  0.014700 -0.019469  0.010368
# father      1.000000 -0.812592 -0.161285
# mother     -0.812592  1.000000 -0.444143
# other      -0.161285 -0.444143  1.000000
#
# [40 rows x 40 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df.corr(),square=True,annot=True,linewidth=0.5)

# %%
df['G1']=(df['G1']+df['G2']+df['G3'])/3

# %%
df['G1']
# Out:
# 0       5.666667
# 1       5.333333
# 2       8.333333
# 3      14.666667
# 4       8.666667
#          ...
# 390     9.000000
# 391    15.333333
# 392     8.333333
# 393    11.000000
# 394     8.666667
# Name: G1, Length: 395, dtype: float64

# %%
df.drop(columns=['G2','G3'],inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

# %%
df.columns.values
# Out:
# array(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'traveltime', 'studytime', 'failures', 'schoolsup',
#        'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet',
#        'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'health',
#        'absences', 'G1', 'at_home', 'mhealth', 'other', 'services',
#        'teacher', 'at_home', 'fhealth', 'other', 'services', 'teacher',
#        'course', 'home', 'other', 'reputation', 'father', 'mother',
#        'other'], dtype=object)

# %%
df.columns.values
# Out:
# array(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'traveltime', 'studytime', 'failures', 'schoolsup',
#        'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet',
#        'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'health',
#        'absences', 'G1', 'at_home', 'mhealth', 'other', 'services',
#        'teacher', 'at_home', 'fhealth', 'other', 'services', 'teacher',
#        'course', 'home', 'other', 'reputation', 'father', 'mother',
#        'other'], dtype=object)

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu  traveltime  studytime  \
# 0      1   0   18       1       1       0     4     4           2          2
# 1      1   0   17       1       1       1     1     1           1          2
# 2      1   0   15       1       0       1     1     1           1          2
# 3      1   0   15       1       1       1     4     2           1          3
# 4      1   0   16       1       1       1     3     3           1          2
#
#    ...  other  services  teacher  course  home  other  reputation  father  \
# 0  ...      0         0        1       1     0      0           0       0
# 1  ...      1         0        0       1     0      0           0       1
# 2  ...      1         0        0       0     0      1           0       0
# 3  ...      0         1        0       0     1      0           0       0
# 4  ...      1         0        0       0     1      0           0       1
#
#    mother  other
# 0       1      0
# 1       0      0
# 2       1      0
# 3       1      0
# 4       0      0
#
# [5 rows x 43 columns]

# %%
df.drop(columns=['Walc'])

# %%
df.columns.values
# Out:
# array(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'traveltime', 'studytime', 'failures', 'schoolsup',
#        'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet',
#        'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'health',
#        'absences', 'G1', 'at_home', 'mhealth', 'other', 'services',
#        'teacher', 'at_home', 'fhealth', 'other', 'services', 'teacher',
#        'course', 'home', 'other', 'reputation', 'father', 'mother',
#        'other'], dtype=object)

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu  traveltime  studytime  \
# 0      1   0   18       1       1       0     4     4           2          2
# 1      1   0   17       1       1       1     1     1           1          2
# 2      1   0   15       1       0       1     1     1           1          2
# 3      1   0   15       1       1       1     4     2           1          3
# 4      1   0   16       1       1       1     3     3           1          2
#
#    ...  other  services  teacher  course  home  other  reputation  father  \
# 0  ...      0         0        1       1     0      0           0       0
# 1  ...      1         0        0       1     0      0           0       1
# 2  ...      1         0        0       0     0      1           0       0
# 3  ...      0         1        0       0     1      0           0       0
# 4  ...      1         0        0       0     1      0           0       1
#
#    mother  other
# 0       1      0
# 1       0      0
# 2       1      0
# 3       1      0
# 4       0      0
#
# [5 rows x 43 columns]

# %%
feature_cols=['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
       'Fedu', 'traveltime', 'studytime', 'failures', 'schoolsup',
       'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet',
       'romantic', 'famrel', 'freetime', 'goout', 'health',
       'absences', 'G1', 'at_home', 'mhealth', 'other', 'services',
       'teacher', 'at_home', 'fhealth', 'other', 'services', 'teacher',
       'course', 'home', 'other', 'reputation', 'father', 'mother',
       'other']

# %%
X=df[feature_cols]
y=df['Dalc']
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu  traveltime  studytime  \
# 0      1   0   18       1       1       0     4     4           2          2
# 1      1   0   17       1       1       1     1     1           1          2
# 2      1   0   15       1       0       1     1     1           1          2
# 3      1   0   15       1       1       1     4     2           1          3
# 4      1   0   16       1       1       1     3     3           1          2
#
#    ...  other  services  teacher  course  home  other  reputation  father  \
# 0  ...      0         0        1       1     0      0           0       0
# 1  ...      1         0        0       1     0      0           0       1
# 2  ...      1         0        0       0     0      1           0       0
# 3  ...      0         1        0       0     1      0           0       0
# 4  ...      1         0        0       0     1      0           0       1
#
#    mother  other
# 0       1      0
# 1       0      0
# 2       1      0
# 3       1      0
# 4       0      0
#
# [5 rows x 43 columns]

# %%
X
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu  traveltime  \
# 0        1   0   18       1       1       0     4     4           2
# 1        1   0   17       1       1       1     1     1           1
# 2        1   0   15       1       0       1     1     1           1
# 3        1   0   15       1       1       1     4     2           1
# 4        1   0   16       1       1       1     3     3           1
# ..     ...  ..  ...     ...     ...     ...   ...   ...         ...
# 390      0   1   20       1       0       0     2     2           1
# 391      0   1   17       1       0       1     3     1           2
# 392      0   1   21       0       1       1     1     1           1
# 393      0   1   18       0       0       1     3     2           3
# 394      0   1   19       1       0       1     1     1           1
#
#      studytime  ...  other  other  other  reputation  father  mother  other  \
# 0            2  ...      0      0      0           0       0       1      0
# 1            2  ...      1      0      0           0       1       0      0
# 2            2  ...      1      1      0           0       0       1      0
# 3            3  ...      0      0      0           0       0       1      0
# 4            2  ...      1      0      0           0       1       0      1
# ..         ...  ...    ...    ...    ...         ...     ...     ...    ...
# 390          2  ...      0      0      1           0       0       0      0
# 391          1  ...      0      0      0           0       0       1      0
# 392          1  ...      1      0      1           0       0       0      1
# 393          1  ...      1      0      0           0       0       1      0
# 394          1  ...      0      0      0           0       1       0      1
#
#      other  other  other
# 0        0      0      0
# 1        1      0      0
# 2        1      1      0
# 3        0      0      0
# 4        1      0      0
# ..     ...    ...    ...
# 390      0      0      1
# 391      0      0      0
# 392      1      0      1
# 393      1      0      0
# 394      0      0      0
#
# [395 rows x 60 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 390    1
# 391    1
# 392    1
# 393    1
# 394    1
# Name: Dalc, Length: 395, dtype: int64

# %%
df['schoolsup']
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 390    0
# 391    0
# 392    0
# 393    0
# 394    0
# Name: schoolsup, Length: 395, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.precision_score(y_test, y_pred))
print("Recall:", metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.680672268907563
# Precision: 0.21428571428571427
# Recall: 0.2727272727272727

# %%
from  sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

model = RandomForestClassifier(n_jobs=-1, n_estimators=100, random_state=42)
model =model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.precision_score(y_test, y_pred))
print("Recall:", metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.8319327731092437
# Precision: 1.0
# Recall: 0.09090909090909091

# %%
def plot_feature_importance(model, X_train, figsize=(12, 6)):
    sns.set_style('darkgrid')
    
    # Plot feature importance
    feature_importance = model.feature_importances_
    feature_importance = 100.0 * (feature_importance / feature_importance.max())
    sorted_idx = np.argsort(feature_importance)
    pos = np.arange(sorted_idx.shape[0]) + .5

    plt.figure(figsize=figsize)
    plt.barh(pos, feature_importance[sorted_idx], align='center')
    plt.yticks(pos, X_train.columns[sorted_idx])
    plt.xlabel('Relative Importance')
    plt.title('Variable Importance')
    plt.show()

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.7, random_state=10)

# %%
list(X_train.columns.values) == list(X_val.columns.values)
# Out:
# True

# %%
from  sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

model = RandomForestClassifier(n_jobs=-1 ,n_estimators=500, random_state=40)
model =model.fit(X_train, y_train)

y_pred = model.predict(X_val)

print("Accuracy:", metrics.accuracy_score(y_val, y_pred))
print("Precision:", metrics.precision_score(y_val, y_pred))
print("Recall:", metrics.recall_score(y_val, y_pred))
# Out:
# Accuracy: 0.8192771084337349
# Precision: 1.0
# Recall: 0.0625

# %%
plot_feature_importance(model, X_train, (10, 30))

# %%
df.columns.values
# Out:
# array(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'traveltime', 'studytime', 'failures', 'schoolsup',
#        'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet',
#        'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'health',
#        'absences', 'G1', 'at_home', 'mhealth', 'other', 'services',
#        'teacher', 'at_home', 'fhealth', 'other', 'services', 'teacher',
#        'course', 'home', 'other', 'reputation', 'father', 'mother',
#        'other'], dtype=object)

# %%
from sklearn.ensemble import ExtraTreesClassifier
extr_clf = ExtraTreesClassifier(n_estimators=500, n_jobs=-1, random_state=42)
extr_clf.fit(X_train, y_train)
y_pred_ext = extr_clf.predict(X_val)

print("Accuracy:", metrics.accuracy_score(y_val, y_pred_ext))
print("Precision:", metrics.precision_score(y_val, y_pred_ext))
print("Recall:", metrics.recall_score(y_val, y_pred_ext))
f1_score(y_val,y_pred_ext)
# Out:
# Accuracy: 0.8313253012048193
# Precision: 1.0
# Recall: 0.125
# 0.2222222222222222

# %%
df.columns.values
# Out:
# array(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'traveltime', 'studytime', 'failures', 'schoolsup',
#        'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet',
#        'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'health',
#        'absences', 'G1', 'at_home', 'mhealth', 'other', 'services',
#        'teacher', 'at_home', 'fhealth', 'other', 'services', 'teacher',
#        'course', 'home', 'other', 'reputation', 'father', 'mother',
#        'other'], dtype=object)

# %%
df.drop(columns=['other','teacher','at_home'],inplace=True)

# %%
pip install xgboost
# Out:
# Collecting xgboostNote: you may need to restart the kernel to use updated packages.
#   Downloading xgboost-1.2.1-py3-none-win_amd64.whl (86.5 MB)
# Requirement already satisfied: scipy in c:\users\bbmum\anaconda3\lib\site-packages (from xgboost) (1.5.0)
# Requirement already satisfied: numpy in c:\users\bbmum\anaconda3\lib\site-packages (from xgboost) (1.18.5)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.2.1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.7, random_state=10) 
model = ExtraTreesClassifier(n_jobs=-1 ,n_estimators=500, random_state=40)
model =model.fit(X_train, y_train)



y_pred = model.predict(X_val)

print("Accuracy:", metrics.accuracy_score(y_val, y_pred))
print("Precision:", metrics.precision_score(y_val, y_pred))
print("Recall:", metrics.recall_score(y_val, y_pred))
# Out:
# Accuracy: 0.8313253012048193
# Precision: 1.0
# Recall: 0.125

# %%
plot_feature_importance(model, X_train, (10, 30))

# %%
df.columns.values
# Out:
# array(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'traveltime', 'studytime', 'failures', 'schoolsup',
#        'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet',
#        'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'health',
#        'absences', 'G1', 'mhealth', 'services', 'fhealth', 'services',
#        'course', 'home', 'reputation', 'father', 'mother'], dtype=object)

# %%
fea_cols=['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
       'Fedu', 'traveltime', 'studytime', 'failures', 'schoolsup',
       'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet',
       'romantic', 'famrel', 'freetime', 'goout', 'health',
       'absences', 'G1', 'mhealth', 'services', 'fhealth', 'services',
       'course', 'home', 'reputation', 'father', 'mother']

# %%
X= df[fea_cols]
y=df['Dalc']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.7, random_state=10) 
model = ExtraTreesClassifier(n_jobs=-1 ,n_estimators=500, random_state=40)
model =model.fit(X_train, y_train)



y_pred = model.predict(X_val)

print("Accuracy:", metrics.accuracy_score(y_val, y_pred))
print("Precision:", metrics.precision_score(y_val, y_pred))
print("Recall:", metrics.recall_score(y_val, y_pred))
# Out:
# Accuracy: 0.8554216867469879
# Precision: 0.8333333333333334
# Recall: 0.3125

# %%
plot_feature_importance(model, X_train, (10, 30))

# %%
df.drop(columns=['Pstatus','schoolsup','mhealth','fhealth','mother','services','internet','reputation','father'],inplace=True)

# %%
df.columns.values
# Out:
# array(['school', 'sex', 'age', 'address', 'famsize', 'Medu', 'Fedu',
#        'traveltime', 'studytime', 'failures', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'health', 'absences', 'G1', 'course',
#        'home'], dtype=object)

# %%
fe_cols=['school', 'sex', 'age', 'address', 'famsize', 'Medu', 'Fedu',
       'traveltime', 'studytime', 'failures', 'famsup', 'paid',
       'activities', 'nursery', 'higher', 'romantic', 'famrel',
       'freetime', 'goout', 'health', 'absences', 'G1', 'course',
       'home']

# %%
X= df[fe_cols]
y=df['Dalc']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.7, random_state=10) 
model = ExtraTreesClassifier(n_jobs=-1 ,n_estimators=500, random_state=40)
model =model.fit(X_train, y_train)



y_pred = model.predict(X_val)

print("Accuracy:", metrics.accuracy_score(y_val, y_pred))
print("Precision:", metrics.precision_score(y_val, y_pred))
print("Recall:", metrics.recall_score(y_val, y_pred))
# Out:
# Accuracy: 0.8554216867469879
# Precision: 0.8333333333333334
# Recall: 0.3125

# %%
plot_feature_importance(model, X_train, (10, 9))

# %%
df.drop(columns=['failures','famrel','traveltime','activities','famsup','paid','home','romantic','address','famsize','nursery','school','course','higher'],inplace=True)

# %%
df.columns.values
# Out:
# array(['sex', 'age', 'Medu', 'Fedu', 'studytime', 'freetime', 'goout',
#        'Dalc', 'health', 'absences', 'G1'], dtype=object)

# %%
f_cols=['sex', 'age', 'Medu', 'Fedu', 'studytime', 'freetime', 'goout', 'health', 'absences', 'G1']

# %%
X= df[f_cols]
y=df['Dalc']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.7, random_state=10) 
model = ExtraTreesClassifier(n_jobs=-1 ,n_estimators=500, random_state=40)
model =model.fit(X_train, y_train)



y_pred = model.predict(X_val)

print("Accuracy:", metrics.accuracy_score(y_val, y_pred))
print("Precision:", metrics.precision_score(y_val, y_pred))
print("Recall:", metrics.recall_score(y_val, y_pred))
# Out:
# Accuracy: 0.8795180722891566
# Precision: 0.875
# Recall: 0.4375

# %%
plot_feature_importance(model, X_train, (10, 9))

# %%
import xgboost as xgb

# %%
df.sex
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 390    1
# 391    1
# 392    1
# 393    1
# 394    1
# Name: sex, Length: 395, dtype: object

# %%
import xgboost as xgb

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.7, random_state=1) 

model = RandomForestClassifier(n_jobs=-1 ,n_estimators=300, random_state=1)

model =model.fit(X_train, y_train)
y_pred = model.predict(X_val)


print(confusion_matrix(y_val,y_pred))

print("Val_Accuracy:", metrics.accuracy_score(y_val, y_pred))
print("Val_Precision:", metrics.precision_score(y_val, y_pred))
print("Val_Recall:", metrics.recall_score(y_val, y_pred))
print("Val_f1_score:",metrics.f1_score(y_val,y_pred))

real_y = model.predict(X_test)
print(confusion_matrix(y_test,real_y))

print("Real_Accuracy:", metrics.accuracy_score(y_test, real_y))
print("Real_Precision:", metrics.precision_score(y_test, real_y))
print("Real_Recall:", metrics.recall_score(y_test, real_y))
print("Real_f1_score:",metrics.f1_score(y_test,real_y))

plot_feature_importance(model, X_train, (10, 9))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-349-e862ac12bddb> in <module>
#       8
#       9
# ---> 10 print(confusion_matrix(y_val,y_pred))
#      11
#      12 print("Val_Accuracy:", metrics.accuracy_score(y_val, y_pred))
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.preprocessing import RobustScaler

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)

scaler= RobustScaler()
scaler.fit(X)

X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

y_pred = clf.predict(X_test)

print(confusion_matrix(y_test,y_pred))

print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.precision_score(y_test, y_pred))
print("Recall:", metrics.recall_score(y_test, y_pred))
f1_score(y_test,y_pred)
# Out:
# [[97  0]
#  [22  0]]
# Accuracy: 0.8151260504201681
# Precision: 0.0
# Recall: 0.0
# C:\Users\bbmum\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.7, random_state=1) 

scaler= RobustScaler()
scaler.fit(X)

X_train=scaler.transform(X_train)
X_val=scaler.transform(X_val)
X_test=scaler.transform(X_test)

clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_val)

print(confusion_matrix(y_val,y_pred))

print("Val_Accuracy:", metrics.accuracy_score(y_val, y_pred))
print("Val_Precision:", metrics.precision_score(y_val, y_pred))
print("Val_Recall:", metrics.recall_score(y_val, y_pred))
print("Val_f1_score:",metrics.f1_score(y_val,y_pred))

real_y = clf.predict(X_test)
print(confusion_matrix(y_test,real_y))

print("Real_Accuracy:", metrics.accuracy_score(y_test, real_y))
print("Real_Precision:", metrics.precision_score(y_test, real_y))
print("Real_Recall:", metrics.recall_score(y_test, real_y))
print("Real_f1_score:",metrics.f1_score(y_test,real_y))
# Out:
# [[55 14]
#  [ 8  6]]
# Val_Accuracy: 0.7349397590361446
# Val_Precision: 0.3
# Val_Recall: 0.42857142857142855
# Val_f1_score: 0.3529411764705882
# [[81 16]
#  [ 9 13]]
# Real_Accuracy: 0.7899159663865546
# Real_Precision: 0.4482758620689655
# Real_Recall: 0.5909090909090909
# Real_f1_score: 0.5098039215686274

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.7, random_state=1) 

model = RandomForestClassifier(n_jobs=-1 ,n_estimators=300, random_state=1)

model =model.fit(X_train, y_train)
y_pred = model.predict(X_val)


print(confusion_matrix(y_val,y_pred))

print("Val_Accuracy:", metrics.accuracy_score(y_val, y_pred))
print("Val_Precision:", metrics.precision_score(y_val, y_pred))
print("Val_Recall:", metrics.recall_score(y_val, y_pred))
print("Val_f1_score:",metrics.f1_score(y_val,y_pred))

real_y = model.predict(X_test)
print(confusion_matrix(y_test,real_y))

print("Real_Accuracy:", metrics.accuracy_score(y_test, real_y))
print("Real_Precision:", metrics.precision_score(y_test, real_y))
print("Real_Recall:", metrics.recall_score(y_test, real_y))
print("Real_f1_score:",metrics.f1_score(y_test,real_y))

plot_feature_importance(model, X_train, (10, 9))
# Out:
# [[67  2]
#  [12  2]]
# Val_Accuracy: 0.8313253012048193
# Val_Precision: 0.5
# Val_Recall: 0.14285714285714285
# Val_f1_score: 0.22222222222222224
# [[93  4]
#  [16  6]]
# Real_Accuracy: 0.8319327731092437
# Real_Precision: 0.6
# Real_Recall: 0.2727272727272727
# Real_f1_score: 0.37499999999999994

# %%
#ExtraTreesClassifire max depth none, GINI
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.7, random_state=1) 

model = ExtraTreesClassifier(n_jobs=-1 ,n_estimators=500, random_state=40)

model =model.fit(X_train, y_train)

y_pred = model.predict(X_val)
print(confusion_matrix(y_val,y_pred))
print("Val_Accuracy:", metrics.accuracy_score(y_val, y_pred))
print("Val_Precision:", metrics.precision_score(y_val, y_pred))
print("Val_Recall:", metrics.recall_score(y_val, y_pred))
print("Val_f1_score:",metrics.f1_score(y_val,y_pred))

real_y = model.predict(X_test)
print(confusion_matrix(y_test,real_y))

print("Real_Accuracy:", metrics.accuracy_score(y_test, real_y))
print("Real_Precision:", metrics.precision_score(y_test, real_y))
print("Real_Recall:", metrics.recall_score(y_test, real_y))
print("Real_f1_score:",metrics.f1_score(y_test,real_y))

plot_feature_importance(model, X_train, (10, 9))
# Out:
# [[67  2]
#  [10  4]]
# Val_Accuracy: 0.8554216867469879
# Val_Precision: 0.6666666666666666
# Val_Recall: 0.2857142857142857
# Val_f1_score: 0.4
# [[92  5]
#  [15  7]]
# Real_Accuracy: 0.8319327731092437
# Real_Precision: 0.5833333333333334
# Real_Recall: 0.3181818181818182
# Real_f1_score: 0.4117647058823529
